# %%
import mysql.connector as sql
import pandas as pd

# %%
File_1 = "youtube_dataset.csv"

# %%
df = pd.read_csv(File_1, encoding='latin-1')
df
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 3939   1553037913-3921  https://socialblade.com/youtube/top/5000/mosts...
# 3940    1553024302-913  https://socialblade.com/youtube/top/5000/mosts...
# 3941   1553034470-3276  https://socialblade.com/youtube/top/5000/mosts...
# 3942   1553040011-4402  https://socialblade.com/youtube/top/5000/mosts...
# 3943   1553027486-1650  https://socialblade.com/youtube/top/5000/mosts...
#
#                       userID  \
# 0                  PewDiePie
# ...

# %%
#Sort the dataframe on the basis of number of subscribers, highest to lowest

df1 = df.sort_values(by=['subscribers'], axis=0, ascending=False)
df1
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 3939   1553037913-3921  https://socialblade.com/youtube/top/5000/mosts...
# 3940    1553024302-913  https://socialblade.com/youtube/top/5000/mosts...
# 3941   1553034470-3276  https://socialblade.com/youtube/top/5000/mosts...
# 3942   1553040011-4402  https://socialblade.com/youtube/top/5000/mosts...
# 3943   1553027486-1650  https://socialblade.com/youtube/top/5000/mosts...
#
#                       userID  \
# 0                  PewDiePie
# ...

# %%
#SHow the top 1000 records based on channeltype

df2 = df1.iloc[0:1000, 9]
df2
# Out:
# 0      Entertainment
# 1              Music
# 2              Games
# 3               Film
# 4             Sports
#            ...
# 995           Comedy
# 996           People
# 997    Entertainment
# 998            Howto
# 999              NaN
# Name: channeltype, Length: 1000, dtype: object

# %%
df3 = df2.value_counts()
df3
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# News              17
# Sports            17
# Autos              3
# Animals            2
# Travel             1
# Nonprofit          1
# Name: channeltype, dtype: int64

# %%
# Create a function to calculate the distribution of channeltype from the top 1000 records

import pandas as pd

pd.set_option('display.max_columns', 20)

top_thousand = pd.read_csv('youtube_dataset.csv')

first_thousand = top_thousand.iloc[:1000,:]

# Build a function
def subset_data(df, row_select, col_select):
  # DOCSTRING
  """
  This function is used to dynamically slice data from 
  a users dataframe. 

  row_select: this represents the rows the user wants
  col_select: this is the columns
  """
  # Magic happens
  subset = df.iloc[row_select, col_select]
  
  # return this value
  return subsetb



first_row = subset_data(top_thousand, 0, [0,1,2,3])
tenth_row = subset_data(top_thousand, 10, [0, 1, 2, 3])

for row in range(0, len(first_thousand)):
  print(subset_data(first_thousand, row, [0, 1, 2]))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xea in position 3: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-835530f89837> in <module>
#       5 pd.set_option('display.max_columns', 20)
#       6
# ----> 7 top_thousand = pd.read_csv('youtube_dataset.csv')
#       8
#       9 first_thousand = top_thousand.iloc[:1000,:]
#
# ...

# %%
#Call the function defined

subset_data(df2, 1000, 20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-34c8a91dece2> in <module>
#       1 #Call the function defined
#       2
# ----> 3 subset_data(df2, 1000, 20)
#
# <ipython-input-27-fea30d06b042> in subset_data(df, row_select, col_select)
#      20   """
#      21   # Magic happens
# ---> 22   subset = df.iloc[row_select, col_select]
#      23
#      24   # return this value
#
# ~\.conda\envs\data1202\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\data1202\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
# ...

# %%
#Sorting of top 1000 records of the orignial 4000 on the basis of subscribers
# df4 = df.sort_values(by=['subscribers'], axis=0, ascending=False)

df4 = df1.iloc[0:1000, 0:20]
df4
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1     1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2     1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3     1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4     1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ..                ...                                                ...
# 995   1553037784-3900  https://socialblade.com/youtube/top/5000/mosts...
# 996   1553037792-3901  https://socialblade.com/youtube/top/5000/mosts...
# 997   1553037768-3897  https://socialblade.com/youtube/top/5000/mosts...
# 998   1553037724-3888  https://socialblade.com/youtube/top/5000/mosts...
# 999   1553037758-3896  https://socialblade.com/youtube/top/5000/mosts...
#
#              userID                                        userID-href  \
# ...

# %%
#Load only the top 1000 records of the original into a seperate CSV file
df4.to_csv("top_1000.csv")
